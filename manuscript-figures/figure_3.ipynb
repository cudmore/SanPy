# %% [markdown]
# ## Explore data and analysis.

# %% [markdown]
# Here we will reproduce a figure from the manuscript. We will start by loading and analyzing some files. We will then make some plots.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt  # just to show plots during script
import seaborn as sns

import sanpy

from sanpy.sanpyLogger import get_logger
logger = get_logger(__name__)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load some sample data.
#
# `jupyter notebook` needs to be run from SanPy/ folder

# %%
# list of files to analyze
aDict = {
    '19503001': {
        'path': 'data/19503001.abf',
        'detectionType': 'dvdt',
        'dvdtThreshold': 60,  # chosen by visual inspection
        'controlSec': [10, 90],
        'isoSec': [210, 300],
    },
    '19503006': {
        'path': 'data/19503006.abf',
        'detectionType': 'dvdt',
        'dvdtThreshold': 18,  # chosen by visual inspection
        'controlSec': [10, 90],
        'isoSec': [180, 270],
    },
    '20191122_0001': {
        # IMPORTANT: The recording chagegd too much in this recording !!!!
        # these changes are not due to ISO and in opposite direction from expected (which is good)!!!
        'path': 'data/20191122_0001.abf',
        'detectionType': 'mv',
        #'dvdtThreshold': 50,
        'mvThreshold': -40,
        'controlSec': [10, 90],
        'isoSec': [380, 470],
    },
}

# %%
# load each file and perform spike detection

# todo: split this into (i) loading which is dead simple and then (ii) creating pandas dataframes
# return to API to make creation of pooled dataframes more simpe

baList = []
dfList = []
dfMaster = None
for idx, (file, params) in enumerate(aDict.items()):

    filePath = params['path']
    detectionType = params['detectionType']
    controlSec = params['controlSec']
    isoSec = params['isoSec']

    # load
    ba = sanpy.bAnalysis(filePath)
    baList.append(ba)
    
    # analyze spikes
    # detectionClass = ba.detectionClass  # Default detection values
    detectionClass = sanpy.bDetection()

    _dDict = detectionClass.getDetectionDict('SA Node')

    _dDict['verbose'] = False
    _dDict['detectionType'] = detectionType
    
    ba.spikeDetect(_dDict)

    # grab results as a pandas dataframe
    df = ba.asDataFrame()

    # todo: merge into big dataframe, add column 'myCellNumber'

    # pull control versus drug stats based on time
    # could do this as well
    #thresholdSec = ba.getStat('thresholdSec', asArray=True)

    # boolean mask based on a time window
    thresholdSec = df['thresholdSec']
    controlMask = (thresholdSec>controlSec[0]) & (thresholdSec<controlSec[1])
    isoMask = (thresholdSec>isoSec[0]) & (thresholdSec<isoSec[1])

    df['myCondition'] = 'None'
    df['myCondition'] = np.where(controlMask, 'Control', df['myCondition'])
    df['myCondition'] = np.where(isoMask, 'Iso', df['myCondition'])

    # Remove .abf from 'file'
    df['myFile'] = df['file'].replace('.abf', '')
    
    if dfMaster is None:
        dfMaster = df
    else:
        dfMaster.append(df, ignore_index=True)
        
    dfList.append(df)
    
    # drop any remaining datapoint (rows) with myCondition == 'None'
    dfPlot = df.drop(df[df['myCondition'] == 'None'].index)
# Out:
#  INFO sanpy.fileloaders.fileLoader_base  fileLoader_base.py __init__() line:202 -- data/19503001.abf
#  INFO sanpy.fileloaders.fileLoader_abf  fileLoader_abf.py _loadAbf() line:121 -- acqDate:"2019-05-03
#  INFO sanpy.fileloaders.fileLoader_abf  fileLoader_abf.py _loadAbf() line:122 -- acqTime:"14:57:45
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:50 -- Loading user analysis plugins
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:74 --
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:75 --    file:
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:76 --    /Users/cudmore/Documents/SanPy-User-Files/analysis/exampleUserAnalysis.py
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:77 --    fullModuleName: sanpy.user_analysis.exampleUserAnalysis
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:78 --    moduleName: exampleUserAnalysis
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:79 --    loadedModule: <module 'sanpy.user_analysis.exampleUserAnalysis' from '/Users/cudmore/Documents/SanPy-User-Files/analysis/exampleUserAnalysis.py'>
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:88 --     oneConstructor: <class 'sanpy.user_analysis.exampleUserAnalysis.exampleUserAnalysis'>
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:89 --     type(oneConstructor): <class 'type'>
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:110 --   loading user analysis from file: "/Users/cudmore/Documents/SanPy-User-Files/analysis/exampleUserAnalysis.py"
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:115 -- Loading core analysis plugins from sanpy.user_analysis
#  INFO sanpy.fileloaders.fileLoader_base  fileLoader_base.py __init__() line:202 -- data/19503006.abf
#  INFO sanpy.fileloaders.fileLoader_abf  fileLoader_abf.py _loadAbf() line:121 -- acqDate:"2019-05-03
#  INFO sanpy.fileloaders.fileLoader_abf  fileLoader_abf.py _loadAbf() line:122 -- acqTime:"15:27:45
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:50 -- Loading user analysis plugins
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:74 --
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:75 --    file:
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:76 --    /Users/cudmore/Documents/SanPy-User-Files/analysis/exampleUserAnalysis.py
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:77 --    fullModuleName: sanpy.user_analysis.exampleUserAnalysis
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:78 --    moduleName: exampleUserAnalysis
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:79 --    loadedModule: <module 'sanpy.user_analysis.exampleUserAnalysis' from '/Users/cudmore/Documents/SanPy-User-Files/analysis/exampleUserAnalysis.py'>
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:88 --     oneConstructor: <class 'sanpy.user_analysis.exampleUserAnalysis.exampleUserAnalysis'>
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:89 --     type(oneConstructor): <class 'type'>
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:110 --   loading user analysis from file: "/Users/cudmore/Documents/SanPy-User-Files/analysis/exampleUserAnalysis.py"
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:115 -- Loading core analysis plugins from sanpy.user_analysis
# /var/folders/76/6bdl7smj72g6tynz3985xxl40000gn/T/ipykernel_44318/3122290772.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfMaster.append(df, ignore_index=True)
#  INFO sanpy.fileloaders.fileLoader_base  fileLoader_base.py __init__() line:202 -- data/20191122_0001.abf
#  INFO sanpy.fileloaders.fileLoader_abf  fileLoader_abf.py _loadAbf() line:121 -- acqDate:"2006-02-18
#  INFO sanpy.fileloaders.fileLoader_abf  fileLoader_abf.py _loadAbf() line:122 -- acqTime:"05:48:40
# WARNING sanpy.fileloaders.fileLoader_abf  fileLoader_abf.py _loadAbf() line:131 --     SanPy does not work with multi-channel recordings numChannels is 2 data/20191122_0001.abf
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:50 -- Loading user analysis plugins
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:74 --
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:75 --    file:
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:76 --    /Users/cudmore/Documents/SanPy-User-Files/analysis/exampleUserAnalysis.py
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:77 --    fullModuleName: sanpy.user_analysis.exampleUserAnalysis
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:78 --    moduleName: exampleUserAnalysis
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:79 --    loadedModule: <module 'sanpy.user_analysis.exampleUserAnalysis' from '/Users/cudmore/Documents/SanPy-User-Files/analysis/exampleUserAnalysis.py'>
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:88 --     oneConstructor: <class 'sanpy.user_analysis.exampleUserAnalysis.exampleUserAnalysis'>
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:89 --     type(oneConstructor): <class 'type'>
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:110 --   loading user analysis from file: "/Users/cudmore/Documents/SanPy-User-Files/analysis/exampleUserAnalysis.py"
#  INFO sanpy.user_analysis.baseUserAnalysis  baseUserAnalysis.py _getObjectList() line:115 -- Loading core analysis plugins from sanpy.user_analysis
# /var/folders/76/6bdl7smj72g6tynz3985xxl40000gn/T/ipykernel_44318/3122290772.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfMaster.append(df, ignore_index=True)

# %%
statName = 'widths_50'

palette_muted = {
    "Control": "#222222",
    "Iso": "#dd1111",
    "None": "#dddddd",
    }
palette = {
    "Control": "k",
    "Iso": "r",
    "None": "#dddddd",
    }

# %%
# work on one ba
ba = baList[0]
filename = ba.getFileName()
oneDf = dfList[0]

# %%
bap = sanpy.bAnalysisPlot(ba)
bap.plotSpikes(plotThreshold=False, plotPeak=True)
# Out:
# <Axes: xlabel='sec', ylabel='mV'>

# %%
# plot raw the vm and dvdt
bap = sanpy.bAnalysisPlot(ba)  # A plot object that provides different kinds of plots
fig, axs = bap.plotDerivAndRaw()

# overlay detected spikes on vm
# see the following for full list of names and meaning of detected parameters
# https://cudmore.github.io/SanPy/methods/#analysis-output
statName = 'thresholdVal'
statName = 'peakVal'
sns.scatterplot(x='thresholdSec', y=statName, hue='myCondition', palette=palette_muted, data=oneDf, ax=axs[0])
# Out:
# <Axes: xlabel='sec', ylabel='mV'>

# %%
statName = 'spikeFreq_hz'
#statName = 'widths_50'
#statName = 'thresholdVal'

fig, axs = plt.subplots(1,2, figsize=(12,6))

# as a time-series
myScatter = sns.scatterplot(x='thresholdSec', y=statName, hue='myCondition', palette=palette, data=oneDf, ax=axs[0])

# as a category
#sns.catplot(x="myCondition", y=statName, kind="swarm", data=dfPlot)

mySwarm = sns.swarmplot(x='myCondition', y=statName, palette=palette_muted, data=oneDf, zorder=1, ax=axs[1])
myPoint = sns.pointplot(x='myCondition', y=statName, palette=palette, data=oneDf, ci=68, ax=axs[1])
# Out:
# /var/folders/76/6bdl7smj72g6tynz3985xxl40000gn/T/ipykernel_44318/1057261223.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   mySwarm = sns.swarmplot(x='myCondition', y=statName, palette=palette_muted, data=oneDf, zorder=1, ax=axs[1])
# /var/folders/76/6bdl7smj72g6tynz3985xxl40000gn/T/ipykernel_44318/1057261223.py:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   myPoint = sns.pointplot(x='myCondition', y=statName, palette=palette, data=oneDf, ci=68, ax=axs[1])
# /var/folders/76/6bdl7smj72g6tynz3985xxl40000gn/T/ipykernel_44318/1057261223.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   myPoint = sns.pointplot(x='myCondition', y=statName, palette=palette, data=oneDf, ci=68, ax=axs[1])

# %% [markdown]
# And finally, a violyn plot

# %%
myViolin = sns.violinplot(x='myCondition', y=statName, palette=palette, data=oneDf)
# Out:
# /var/folders/76/6bdl7smj72g6tynz3985xxl40000gn/T/ipykernel_44318/4256430603.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   myViolin = sns.violinplot(x='myCondition', y=statName, palette=palette, data=oneDf)

# %%
# show some summary statistics between groups
aggDict = {
    statName: ['min', 'max', 'mean', 'sem', 'count'],
}

oneDf.groupby(['myCondition']).agg(aggDict)
# Out:
#             spikeFreq_hz
#                      min       max      mean       sem count
# myCondition
# Control         0.060095  3.238342  0.837955  0.153440    25
# Iso             0.270523  2.719608  1.197933  0.061217    84
# None            0.054773  3.354016  0.945898  0.087790    68

# %%
# do statistics
# for now we are just doing a t-test, we may be breaking a lot of assumptions! Left as a homewok assignment.

condition = 'Control'
controlRows = oneDf[ oneDf['myCondition']==condition] 
controlValues = controlRows[statName].tolist()
print('Control n=', len(controlValues))

condition = 'Iso'
isoRows = oneDf[ oneDf['myCondition']==condition] 
isoValues = isoRows[statName].tolist()
print('Iso n=', len(isoValues))

import scipy.stats

print('statName:', statName)
test_t, ttest_p = scipy.stats.ttest_ind(a=controlValues, b=isoValues, equal_var=True)
print(test_t, ttest_p)

kw_h, kw_p = scipy.stats.kruskal(controlValues, isoValues)
print(kw_h, kw_p)
# Out:
# Control n= 25
# Iso n= 84
# statName: spikeFreq_hz
# -2.576076474191216 0.011356585519447092
# 8.478753246753229 0.0035931827267121734

# %%
# plot two stats (similar to thresholdSec above)
xStat = 'spikeFreq_hz'
yStat = 'widths_50'

fig, axs = plt.subplots(1,1, figsize=(3,3))
axs = [axs]

# as a time-series
myScatter = sns.scatterplot(x=xStat, y=yStat, hue='myCondition', palette=palette, data=oneDf, ax=axs[0])
axs[0].spines['right'].set_visible(False)
axs[0].spines['top'].set_visible(False)
