# %% [markdown]
# ### In just a few lines of code, recordings can be: loaded, analyzed, and plotted.

# %%
import sanpy

# load
ba = sanpy.bAnalysis('../../../data/19114001.abf');

# analyze/detect
ba.spikeDetect();

# plot
bap = sanpy.analysisPlot.bAnalysisPlot(ba)
bap.plotSpikes();
# Out:
#  INFO sanpy.bAnalysis  bAnalysis.py __init__() line:47 -- ../../../data/19114001.abf
#  INFO sanpy.bAnalysis  bAnalysis.py spikeDetect() line:928 -- start detection
#  INFO sanpy.bAnalysis  bAnalysis.py _throwOutRefractory() line:628 -- From 103 to 102 spikes with refractory_ms:170
#  INFO sanpy.bAnalysis  bAnalysis.py errorReport() line:1620 -- Found 1 errors in spike detection
#  INFO sanpy.bAnalysis  bAnalysis.py spikeDetect() line:1501 -- Detected 102 spikes in 0.05 seconds
